# %%
import pandas as pd
import numpy as np

# Define column specifications
col_specs = [
    (0, 4, 'YEAR'),
    (4, 6, 'MONTH'),
    (6, 8, 'AGE'),
    (8, 9, 'SEX'),
    (9, 10, 'MARST'),
    (10, 12, 'EMPSTAT'),
    (12, 15, 'OCC1990'),
    (15, 18, 'IND1990'),
    (18, 21, 'UHRSWORKT'),
    (21, 31, 'EARNWT'),
    (31, 32, 'UNION'),
    (32, 40, 'EARNWEEK')
]

# Read the fixed-width file
df = pd.read_fwf(
    "C:\\Me\\thesis\\Thesis code\\data\\cps_00012.dat",
    colspecs=col_specs,
    dtype={'UNION': str}
)

# View UNION field information
print(df['UNION'].value_counts())
print(df['UNION'].value_counts(normalize=True))
print(df['UNION'].isna().sum())
print(df['UNION'].describe())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 21
#       5 col_specs = [
#       6     (0, 4, 'YEAR'),
#       7     (4, 6, 'MONTH'),
#    (...)
#      17     (32, 40, 'EARNWEEK')
#      18 ]
#      20 # Read the fixed-width file
# ---> 21 df = pd.read_fwf(
#      22     "C:\\Me\\thesis\\Thesis code\\data\\cps_00012.dat",
#      23     colspecs=col_specs,
#      24     dtype={'UNION': str}
#      25 )
#      27 # View UNION field information
#      28 print(df['UNION'].value_counts())
#
# File c:\Users\hp\.conda\envs\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1565, in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, dtype_backend, iterator, chunksize, **kwds)
#    1563 check_dtype_backend(dtype_backend)
#    1564 kwds["dtype_backend"] = dtype_backend
# -> 1565 return _read(filepath_or_buffer, kwds)
#
# ...
